# %%
from langchain_community.document_loaders import WebBaseLoader
from pprint import pp
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8784\4086227143.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import WebBaseLoader
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
# create the loader

url_1 = "https://docs.langchain.com/oss/python/integrations/document_loaders/pypdfloader"
url_2 = "https://docs.langchain.com/oss/python/integrations/document_loaders/pdfminer"
url_3 = "https://docs.langchain.com/oss/python/integrations/document_loaders/pdfplumber"

loader = WebBaseLoader(web_paths=[url_1, url_2, url_3])

# %%
documents = loader.load()

# %%
len(documents)
# Out:
# 3

# %%
pp(documents[0].metadata)
# Out:
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/pypdfloader',
#  'language': 'No language found.'}

# %% [markdown]
# ## Recursive Loader

# %%
from langchain_community.document_loaders import RecursiveUrlLoader

# %%
base_url = "https://docs.langchain.com/oss/python/integrations/document_loaders"

loader = RecursiveUrlLoader(url=base_url,
                            max_depth=2)

# %%
documents = loader.load()
# Out:
# c:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_community\document_loaders\recursive_url_loader.py:44: XMLParsedAsHTMLWarning: It looks like you're using an HTML parser to parse an XML document.
#
# Assuming this really is an XML document, what you're doing might work, but you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the Python package 'lxml' installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#
# If you want or need to use an HTML parser on this document, you can make this warning go away by filtering it. To do that, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import XMLParsedAsHTMLWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)
#
#   soup = BeautifulSoup(raw_html, "html.parser")

# %%
len(documents)
# Out:
# 56

# %%
# metadata for first 10 documents

for i in range(10):
    doc = documents[i]

    print(doc.metadata, end="\n\n")
# Out:
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders', 'content_type': 'text/html; charset=utf-8', 'title': 'Document loader integrations - Docs by LangChain', 'description': 'Integrate with document loaders using LangChain Python.', 'language': 'en'}
#
# {'source': 'https://docs.langchain.com/sitemap.xml', 'content_type': 'text/xml'}
#
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/agentql', 'content_type': 'text/html; charset=utf-8', 'title': 'AgentQLLoader integration - Docs by LangChain', 'description': 'Integrate with the AgentQLLoader document loader using LangChain Python.', 'language': 'en'}
#
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/google_cloud_storage_directory', 'content_type': 'text/html; charset=utf-8', 'title': 'Google cloud storage directory integration - Docs by LangChain', 'description': 'Integrate with the Google cloud storage directory document loader using LangChain Python.', 'language': 'en'}
#
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/hyperbrowser', 'content_type': 'text/html; charset=utf-8', 'title': 'HyperbrowserLoader integration - Docs by LangChain', 'description': 'Integrate with the HyperbrowserLoader document loader using LangChain Python.', 'language': 'en'}
#
# {'source': 'https://docs.langchain.com/oss/python/integrations/providers/all_providers', 'content_type': 'text/html; charset=utf-8', 'title': 'All LangChain Python integration providers - Docs by LangChain', 'language': 'en'}
#
# {'source': 'https://docs.langchain.com/oss/python/integrations/chat', 'content_type': 'text/html; charset=utf-8', 'title': 'Chat model integrations - Docs by LangChain', 'description': 'Integrate with chat models using LangChain Python.', 'language': 'en'}
#
# {'source': 'https://docs.langchain.com/oss/python/integrations/providers/microsoft', 'content_type': 'text/html; charset=utf-8', 'title': 'Microsoft integrations - Docs by LangChain', 'description': 'Integrate with Microsoft using LangChain Python.', 'language': 'en'}
#
# {'source': 'https://docs.langchain.com/oss/python/integrations/embeddings', 'content_type': 'text/html; charset=utf-8', 'title': 'Embedding model integrations - Docs by LangChain', 'description': 'Integrate with embedding models using LangChain Python.', 'language': 'en'}
#
# {'source': 'https://docs.langchain.com/oss/python/deepagents/overview', 'content_type': 'text/html; charset=utf-8', 'title': 'Deep Agents overview - Docs by LangChain', 'description': 'Build agents that can plan, use subagents, and leverage file systems for complex tasks', 'language': 'en'}

# %% [markdown]
# ## Lazy Load

# %%
documents_lazy_load = loader.lazy_load()

# %%
documents_lazy_load
# Out:
# <generator object RecursiveUrlLoader._get_child_links_recursive at 0x0000027339D17940>

# %%
counter = 0

for document in documents_lazy_load:
    # stop condition
    if counter == 20:
        break

    # increment the counter
    counter += 1

    # print metadata and page content
    print(document.page_content[0:300])
    pp(document.metadata)
# Out:
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_9db261d6-module__QQJmOa__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/agentql',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'AgentQLLoader integration - Docs by LangChain',
#  'description': 'Integrate with the AgentQLLoader document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_9db261d6-module__QQJmOa__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/google_cloud_storage_directory',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Google cloud storage directory integration - Docs by LangChain',
#  'description': 'Integrate with the Google cloud storage directory document '
#                 'loader using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_9db261d6-module__QQJmOa__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/hyperbrowser',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'HyperbrowserLoader integration - Docs by LangChain',
#  'description': 'Integrate with the HyperbrowserLoader document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_9db261d6-module__QQJmOa__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/providers/all_providers',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'All LangChain Python integration providers - Docs by LangChain',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_9db261d6-module__QQJmOa__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/chat',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Chat model integrations - Docs by LangChain',
#  'description': 'Integrate with chat models using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_9db261d6-module__QQJmOa__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/providers/microsoft',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Microsoft integrations - Docs by LangChain',
#  'description': 'Integrate with Microsoft using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_9db261d6-module__QQJmOa__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/embeddings',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Embedding model integrations - Docs by LangChain',
#  'description': 'Integrate with embedding models using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_9db261d6-module__QQJmOa__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/deepagents/overview',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Deep Agents overview - Docs by LangChain',
#  'description': 'Build agents that can plan, use subagents, and leverage file '
#                 'systems for complex tasks',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_9db261d6-module__QQJmOa__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/polaris_ai_datainsight',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'PolarisAIDataInsightLoader integration - Docs by LangChain',
#  'description': 'Integrate with the PolarisAIDataInsightLoader document loader '
#                 'using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_9db261d6-module__QQJmOa__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/google_cloud_storage_file',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Google cloud storage file integration - Docs by LangChain',
#  'description': 'Integrate with the Google cloud storage file document loader '
#                 'using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_9db261d6-module__QQJmOa__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/middleware',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Middleware integrations - Docs by LangChain',
#  'description': 'Integrate with middleware using LangChain Python.',
#  'language': 'en'}
# :root{--twoslash-border-color:#dbdfde;--twoslash-underline-color:currentColor;--twoslash-popup-bg:#f3f7f6;--twoslash-popup-color:inherit;--twoslash-popup-shadow:#00000014 0px 1px 4px;--twoslash-code-font:inherit;--twoslash-code-font-size:1em;--twoslash-matched-color:inherit;--twoslash-highlighted-bo
# {'source': 'https://docs.langchain.com/mintlify-assets/_next/static/chunks/d982485189211ca0.css?dpl=dpl_5NdtJYwamH41ztoWfMfMpB8t5YYx',
#  'content_type': 'text/css; charset=utf-8'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_9db261d6-module__QQJmOa__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/langgraph/overview',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'LangGraph overview - Docs by LangChain',
#  'description': 'Gain control with LangGraph to design agents that reliably '
#                 'handle complex tasks',
#  'language': 'en'}
# wOF2yp|0y?FFTM���n�"`�&
# �*",q5[���t��Z��6,�U�}.��c��bt�V�a�l���P��bvU��˜]*�acG#��͈��+V���3�y&Ba��U�	�'kj?�.6�Z/��*A����A�[�!�H�P�pM,��؃���&AR%7�hb�����
# {'source': 'https://docs.langchain.com/fonts/TWKLausanne-700.woff2',
#  'content_type': 'application/octet-stream, font/woff2'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_9db261d6-module__QQJmOa__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/build-overview',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Build - Docs by LangChain',
#  'description': 'Build agents with LangChain, LangGraph, and Deep Agents.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_9db261d6-module__QQJmOa__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/apify_dataset',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Apify dataset integration - Docs by LangChain',
#  'description': 'Integrate with the Apify dataset document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_9db261d6-module__QQJmOa__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/providers/fireworks',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Fireworks integrations - Docs by LangChain',
#  'description': 'Integrate with Fireworks AI using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_9db261d6-module__QQJmOa__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/undatasio',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Undatasio integration - Docs by LangChain',
#  'description': 'Integrate with the Undatasio document loader using LangChain '
#                 'Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_9db261d6-module__QQJmOa__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/unstructured_file',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Unstructured integration - Docs by LangChain',
#  'description': 'Integrate with the Unstructured document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_9db261d6-module__QQJmOa__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/backends',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Backend integrations - Docs by LangChain',
#  'description': 'Community-built filesystem backends for Deep Agents.',
#  'language': 'en'}
