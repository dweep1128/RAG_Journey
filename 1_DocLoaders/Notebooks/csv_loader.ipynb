# %%
from langchain_community.document_loaders.csv_loader import CSVLoader
from pathlib import Path
from pprint import pp

# %%
# define the path to csv file

file_path = Path("../Knowledge_Source/organizations.csv")
file_path.exists()
# Out:
# True

# %%
loader = CSVLoader(file_path=file_path)

# %%
doc = loader.load()

# %%
len(doc) # eac document in a CSV Loader is a row in the CSV file. So the length of the document is equal to the number of rows in the CSV file.
# Out:
# 1000

# %%
 print(doc[0].page_content) # print the content of the first document (row) in the CSV file.
# Out:
# Index: 1
# Organization Id: E84A904909dF528
# Name: Liu-Hoover
# Website: http://www.day-hartman.org/
# Country: Western Sahara
# Description: Ergonomic zero administration knowledge user
# Founded: 1980
# Industry: Online Publishing
# Number of employees: 6852

# %%
pp(doc[0].metadata)
# Out:
# {'source': '..\\Knowledge_Source\\organizations.csv', 'row': 0}
